# %% [markdown]
# **BAYES**
#
# ![image.png](attachment:image.png)

# %%
likelihood = 1
prior = 5/11

marginalization = likelihood * prior + .5*2/11 + 1/4 * 4/11

posterior = (likelihood * prior) / marginalization
posterior
# Out:
# 0.7142857142857143
