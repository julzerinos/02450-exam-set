# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

z = np.array([1, 3, 3, 1, 2, 3, 1])

v = z.size - 1
mu = z.mean()
std = np.sqrt(np.sum((z - z.mean())**2/(z.size*(z.size-1))))

print(f"Student's t-distribtions will have values v={v}, mu={mu}, std={std}")
# Out:
# Student's t-distribtions will have values v=6, mu=2.0, std=0.3779644730092272
