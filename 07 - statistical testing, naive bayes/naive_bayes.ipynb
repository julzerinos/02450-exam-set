# %% [markdown]
# **NAIVE BAYES**
#
# ![image.png](attachment:image.png)

# %%
likelihood = 2/3 * 2/3 * 2/3
prior = 3/10

marginalization = prior * likelihood + ( ( 1 * 1/2 * 1 ) * 2/10 ) + ( ( 4/5 * 3/5 * 1/5 ) * 5/10)

print("posterior", likelihood * prior / marginalization)
200/533
# Out:
# posterior 0.3752345215759849
# 0.37523452157598497
